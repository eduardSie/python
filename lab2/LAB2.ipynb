# %% [markdown]
# # LAB 2 Бібліотеки numpy та pandas: зображення даних

# %% [markdown]
# <ul>
#     <li><b>Частина 1. Оцінка параметрів функції</b></li>
#
# Блокнот: <code>LAB2 part1 Оцінка часової складності (робочий зошит).ipynb</code>
#
# Оцінити параметри функції, що є часовою складністю. Деталі в блокноті.
# <br> За цією частиною здається повністю заповнений та начисто виконаний блокнот (і сам блокнот, і отриманий за ним pdf-файл).
#
# <li><b>Частина 2. Оброблення табличних даних</b></li>
#
# Блокнот: <code>LAB2 part2 Оброблення даних про файли (робочий зошит).ipynb</code>
#
# У задачі 3 Лабораторної роботи 1 було побудовано файл lab1_1.csv. Завантаживши його у <code>DataFrame</code>, розв'язати задачі 1 та 2 лабораторної роботи 1. Деталі в блокноті.
#
# Про всяк випадок на гугл-диску є приклад файлу lab1_1.csv.
#
# За цією частиною здається повністю заповнений та начисто виконаний блокнот (і сам блокнот, і отриманий за ним pdf-файл).
# Інформація, отримана в цій частині, має корелювати з тим, що було отримано під час виконання лабораторної роботи №1.
#
# <li><b>Частина 3. Оброблення даних про успішність</b></li>
#
# Блокнот: <code>LAB2 part3 Оброблення даних про успішність (робочий зошит).ipynb</code>
# <br> Деталі в блокноті.
# <br> За цією частиною здається повністю заповнений та начисто виконаний блокнот (і сам блокнот, і отриманий за ним pdf-файл).
#
# <li><b>Частина 4. Визначення часової складності</b></li>
#
# Блокнот: <code>LAB2 part4 Оцінка часової складності (робочий зошит).ipynb</code>
#
# На вхід дається csv-файл, що містить результати вимірювання часу роботи програми. Кожен рядок файлу містить пару чисел: розмір вхідних даних (у байтах) та час роботи на них програми (у мілісекундах).
#
# Гіпотеза полягає в тім, що часова складність досліджуваної програми має вигляд $$T(n) = \Theta(n^a)$$
# Задача: оцінити параметр $a$.
# <br> За цією частиною здається повністю заповнений та начисто виконаний блокнот (і сам блокнот, і отриманий за ним pdf-файл).
# </ul>
#
# <br> <b>Обмеження для всіх частин: використовувати цикли та рекурсію заборонено.</b>

# %% [markdown]
# <b>Здається</b>:
#
# Чотири робочих зошити (заповнені, вилучати клітини, які були в ньому з самого початку, не дозволяється) та pdf-звіт до кожного.
#
# Перед здачею необхідно зробити Kernel -> Restart Kernel and Run All Cells... Для отримання pdf-звіта блокнот можна просто роздрукувати.
#     <br>
#     <b>Увага!</b> Повідомлень про помилки виконання бути не повинно.
# </ol>
#
# <b>Оцінювання (максимум 15 балів)</b>:
#
# Обов'язково мають бути повністю та правильно виконані (у тому числі без повідомлень про помилки) та заповнені робочі зошити (блокноти), мають бути pdf-звіти до них, що відповідають виконаним блокнотам. Це стосується частин 1, 2 та 3.
#
# За відсутності частини 4 або наявності в ній помилок (чи графіка "зигзагами") знімається 3 бали.
#
# Правильність виконання оцінюється з точки зору дотримання вимог та отриманого кінцевого результату.
#
# За неохайні звіти (не були виконані з чистого аркушу перед відправленням) знімається 3 бали.
#
# За використання циклів або рекурсії вся лабораторна №2 оцінюється в нуль балів.
